# %%
import osmnx as ox
import networkx as nx
import folium as folium

# %%
#Place choice and route method
place     = "Padua, Italy"
mode      = "walk"           #'drive', 'bike', 'walk'

#Import geographical information as a graph
graph = ox.graph_from_place(place, network_type = mode)

# %%
#Category of places
tags = {'amenity': 'bar'}

#Import (geo)Pandas DataFrame
cafe = ox.geometries_from_place(place, tags=tags)
cafe = cafe.reset_index()
cafe = cafe[cafe["element_type"] == "node"]
cafe.tail()
# Out:
# /tmp/ipykernel_3294/2807957983.py:5: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   cafe = ox.geometries_from_place(place, tags=tags)
#     element_type        osmid addr:housenumber               addr:street  \
# 127         node  12956988101             93/a             Via dei Colli
# 128         node  12987796798              NaN                       NaN
# 129         node  12993328291               66             Via Capitello
# 130         node  13051898572               93  Via Jacopo da Montagnana
# 131         node  13144971801              2/A           Via del Carmine
#
#     amenity              name phone ref:vatin wifi                   geometry  \
# ...

# %%
import osmnx as ox
import networkx as nx
import folium

# Place choice and route method
place     = "Padua, Italy"
mode      = "walk"           # 'drive', 'bike', 'walk'

# Import geographical information as a graph
graph = ox.graph_from_place(place, network_type=mode)

# Convert to undirected graph (better for plotting)
graph_proj = ox.project_graph(graph)

# Create a folium map centered at Padua
center = [45.4064, 11.8768]  # approximate center of Padua
m = folium.Map(location=center, zoom_start=14, tiles="cartodbpositron")

# Add the graph (nodes + edges) to folium
folium_graph = ox.plot_graph_folium(graph, graph_map=m, popup_attribute="highway", edge_color="blue", edge_width=2)

# Category of places
tags = {'amenity': 'bar'}

# Import (geo)Pandas DataFrame
cafe = ox.geometries_from_place(place, tags=tags)
cafe = cafe.reset_index()
cafe = cafe[cafe["element_type"] == "node"]

# Add cafés as markers on the map
for idx, row in cafe.iterrows():
    lat, lon = row.geometry.y, row.geometry.x
    folium.CircleMarker(
        location=(lat, lon),
        radius=4,
        color="red",
        fill=True,
        fill_opacity=0.7,
        popup=row.get("name", "Unnamed Café")
    ).add_to(folium_graph)

# Show map
folium_graph.save("padua_map.html")
print("✅ Map saved as padua_map.html, open it in your browser.")
# Out:
# /home/codespace/.cache/pypoetry/virtualenvs/ev-energy-optimization-k_wesG8s-py3.12/lib/python3.12/site-packages/osmnx/graph.py:392: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   polygon = gdf_place["geometry"].unary_union
# /tmp/ipykernel_3294/1229118406.py:20: FutureWarning: The `folium` module has been deprecated and will be removed in the v2.0.0 release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   folium_graph = ox.plot_graph_folium(graph, graph_map=m, popup_attribute="highway", edge_color="blue", edge_width=2)
# ...
